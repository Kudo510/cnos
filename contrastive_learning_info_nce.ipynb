# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Create dataset
# Use Sam to extract proposals from input images (100 images) then for proposals with same regions as the ground truth masks, they are considered as positive sameple to the templates ( use the BlenderProc 42 templates), negative otherwise
#
# Run through 100 images - then return positive proposals and negative proposals
#
# Use IoU >0.5 to get the postive proposals

# %% [markdown]
# ## 1.1 Extract positive proposals, negative proposals, anchors

# %%
# # this is the one we use
# from src.model.constrastive_learning import extract_dataset_train_pbr_icbin_obj2

# dataset = "icbin"
# data_type = "train_pbr"
# scene_id = 0
# target_object_id = 2
# pos_proposals, neg_proposals, best_mask_indices = extract_dataset_train_pbr_icbin_obj2(dataset, data_type, scene_id, target_object_id) # Take 2.21 minutes

# %%
# all_pos_proposals = [item for sublist in pos_proposals for item in sublist if item["rgb"] is not None]
# all_neg_proposals = [item for sublist in neg_proposals for item in sublist]
# print("len(all_pos_proposals), len(all_neg_proposals)", len(all_pos_proposals), len(all_neg_proposals))

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Number of images to display at a time
# images_per_page = 25

# # Define the number of rows and columns for the grid
# rows = 5
# cols = 5

# # Iterate over the images in steps of images_per_page
# for i in range(200, 500, images_per_page):
#     # Create a new figure for each set of 25 images
#     plt.figure(figsize=(15, 15))

#     for j in range(images_per_page):
#         # Calculate the current image index
#         image_index = i + j

#         # Check if the image_index is within the bounds of the list
#         if image_index >= len(all_pos_proposals):
#             break

#         # Add a subplot for the current image
#         plt.subplot(rows, cols, j + 1)
#         plt.imshow(np.array(all_pos_proposals[image_index]["rgb"]))
#         plt.title(f"Image {image_index}")
#         plt.axis('off')

#     # Display the figure containing 25 images
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Number of images to display at a time
# images_per_page = 25

# # Define the number of rows and columns for the grid
# rows = 5
# cols = 5

# # Iterate over the images in steps of images_per_page
# for i in range(0, 500, images_per_page):
#     # Create a new figure for each set of 25 images
#     plt.figure(figsize=(15, 15))

#     for j in range(images_per_page):
#         # Calculate the current image index
#         image_index = i + j

#         # Check if the image_index is within the bounds of the list
#         if image_index >= len(all_neg_proposals):
#             break

#         # Add a subplot for the current image
#         plt.subplot(rows, cols, j + 1)
#         plt.imshow(np.array(all_neg_proposals[image_index]))
#         plt.title(f"Image {image_index}")
#         plt.axis('off')

#     # Display the figure containing 25 images
#     plt.show()

# %%
# # Filtering out all wrong image in the neg (it should be ignored)
# # Indices to remove
# indices_to_remove = [
#     16, 48, 49, 67, 82, 100, 171, 180, 201,
#     222, 223, 240, 241, 279, 280, 283, 320,
#     334, 344, 349, 387, 388, 400, 403, 407,
#     408, 411, 412, 417, 419, 421, 442, 458,
#     460, 461, 472, 474, 485
# ]

# # Create a new list excluding the specified indices
# filtered_all_neg_proposals = [item for index, item in enumerate(all_neg_proposals) if index not in indices_to_remove]

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Number of images to display at a time
# images_per_page = 25

# # Define the number of rows and columns for the grid
# rows = 5
# cols = 5

# # Iterate over the images in steps of images_per_page
# for i in range(0, 500, images_per_page):
#     # Create a new figure for each set of 25 images
#     plt.figure(figsize=(15, 15))

#     for j in range(images_per_page):
#         # Calculate the current image index
#         image_index = i + j

#         # Check if the image_index is within the bounds of the list
#         if image_index >= len(filtered_all_neg_proposals):
#             break

#         # Add a subplot for the current image
#         plt.subplot(rows, cols, j + 1)
#         plt.imshow(np.array(filtered_all_neg_proposals[image_index]))
#         plt.title(f"Image {image_index}")
#         plt.axis('off')

#     # Display the figure containing 25 images
#     plt.show()

# %%
# import pickle
# # train_pbr_pos_proposals_obj_2_filtered means dataset with neg only from background not from object 1 
# # train_pbr_pos_proposals_obj_2_filtered_self_rendered is like train_pbr_pos_proposals_obj_2_filtered but the dataset now is render from prbr selbts not from given dataset
# # train_pbr_pos_proposals_obj_2_filtered_self_rendered_ver1 is just that all the neg are now really correct 
# with open('contrastive_learning/outputs/train_pbr_pos_proposals_obj_2_filtered_self_rendered_ver1.pkl', 'wb') as file:
#     pickle.dump(all_pos_proposals, file)

# with open('contrastive_learning/outputs/train_pbr_neg_proposals_obj_2_filtered_self_rendered_ver1.pkl', 'wb') as file:
#     pickle.dump(filtered_all_neg_proposals, file)

# %% [markdown]
# # Start from here

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pickle

# train_pbr_neg_proposals_sam_inside_100_pre_filter is the best one to choose

with open('contrastive_learning/outputs/train_pbr_pos_proposals_sam_inside_100_pre_filter.pkl', 'rb') as file:
    pos = pickle.load(file)

with open('contrastive_learning/outputs/train_pbr_neg_proposals_sam_inside_100_pre_filter.pkl', 'rb') as file:
    neg = pickle.load(file)

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Number of images to display at a time
# images_per_page = 25

# # Define the number of rows and columns for the grid
# rows = 5
# cols = 5

# # Iterate over the images in steps of images_per_page
# for i in range(0, 500, images_per_page):
#     # Create a new figure for each set of 25 images
#     plt.figure(figsize=(15, 15))

#     for j in range(images_per_page):
#         # Calculate the current image index
#         image_index = i + j

#         # Check if the image_index is within the bounds of the list
#         if image_index >= len(neg):
#             break

#         # Add a subplot for the current image
#         plt.subplot(rows, cols, j + 1)
#         plt.imshow(np.array(pos[image_index]["rgb"]))
#         plt.title(f"Image {image_index}")
#         plt.axis('off')

#     # Display the figure containing 25 images
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np

# # Number of images to display at a time
# images_per_page = 25

# # Define the number of rows and columns for the grid
# rows = 5
# cols = 5

# # Iterate over the images in steps of images_per_page
# for i in range(150, 250, images_per_page):
#     # Create a new figure for each set of 25 images
#     plt.figure(figsize=(15, 15))

#     for j in range(images_per_page):
#         # Calculate the current image index
#         image_index = i + j

#         # Check if the image_index is within the bounds of the list
#         if image_index >= len(neg):
#             break

#         # Add a subplot for the current image
#         plt.subplot(rows, cols, j + 1)
#         plt.imshow(np.array(pos_obj_1_without_pose[image_index]))
#         plt.title(f"Image {image_index}")
#         plt.axis('off')

#     # Display the figure containing 25 images
#     plt.show()

# %%
len(pos)
# Out:
# 4288

# %% [markdown]
# ## 1.2 Create positive and negative pairs
# Positive pairs (positive proposal and template with most similar pose)

# %%
import torch

from src.model.contrastive_learning_info_nce import ContrastiveLearningModelInfoNCE


# template_paths = "datasets/bop23_challenge/datasets/templates_pyrender/icbin/obj_000001/*.png"
# template_poses_path = "datasets/bop23_challenge/datasets/templates_pyrender/icbin/template_poses.npy"
template_paths = "foundpose_analysis/icbin/templates/train_pbr/obj_000001_original/*.png"
template_poses_path = "foundpose_analysis/icbin/templates/train_pbr/obj_000001_original/poses.pkl"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ContrastiveLearningModelInfoNCE(device)
# model.load_state_dict(torch.load("contrastive_learning/saved_checkpoints/icbin_best_model_checkpoint.pth"))
# Out:
# [2024-10-17 23:59:09,137] [INFO] src.model.contrastive_learning_info_nce: model used is dinov2_vitl14
# Using cache found in /home/cuong.van-dam/.cache/torch/hub/facebookresearch_dinov2_main
# /home/cuong.van-dam/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/swiglu_ffn.py:43: UserWarning: xFormers is available (SwiGLU)
#   warnings.warn("xFormers is available (SwiGLU)")
# /home/cuong.van-dam/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/attention.py:27: UserWarning: xFormers is available (Attention)
#   warnings.warn("xFormers is available (Attention)")
# /home/cuong.van-dam/.cache/torch/hub/facebookresearch_dinov2_main/dinov2/layers/block.py:33: UserWarning: xFormers is available (Block)
#   warnings.warn("xFormers is available (Block)")
# [2024-10-17 23:59:10,171] [INFO] dinov2: using MLP layer as FFN

# %%
from src.model.contrastive_learning_info_nce import prepare_dataset
train_dataset, val_dataset, test_dataset, val_set = prepare_dataset(
    template_paths, template_poses_path, pos[:1000], neg[:] # build only 1000 postive images
    )
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s][2024-10-18 00:06:57,933] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 58)
# [2024-10-18 00:06:57,981] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 34, 41)
#   0%|          | 2/1000 [00:00<01:01, 16.30it/s][2024-10-18 00:06:58,059] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 45)
# [2024-10-18 00:06:58,144] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 73, 53)
#   0%|          | 4/1000 [00:00<01:28, 11.21it/s][2024-10-18 00:06:58,273] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 23)
# [2024-10-18 00:06:58,348] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 51)
#   1%|          | 6/1000 [00:00<01:27, 11.43it/s][2024-10-18 00:06:58,449] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 18, 47)
# [2024-10-18 00:06:58,544] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 52)
#   1%|          | 8/1000 [00:00<01:27, 11.34it/s][2024-10-18 00:06:58,624] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 30)
# [2024-10-18 00:06:58,747] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 45)
#   1%|          | 10/1000 [00:00<01:46,  9.33it/s][2024-10-18 00:06:58,905] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 67)
# [2024-10-18 00:06:59,019] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 40)
#   1%|          | 12/1000 [00:01<01:43,  9.58it/s][2024-10-18 00:06:59,103] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 23, 50)
# [2024-10-18 00:06:59,212] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 37)
#   1%|▏         | 14/1000 [00:01<01:39,  9.88it/s][2024-10-18 00:06:59,295] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 54)
# [2024-10-18 00:06:59,389] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 117, 124)
#   2%|▏         | 16/1000 [00:01<01:45,  9.32it/s][2024-10-18 00:06:59,538] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 81, 117)
#   2%|▏         | 17/1000 [00:01<01:45,  9.32it/s][2024-10-18 00:06:59,643] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 81, 68)
# [2024-10-18 00:06:59,735] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 59)
#   2%|▏         | 19/1000 [00:01<01:34, 10.35it/s][2024-10-18 00:06:59,797] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 63)
# [2024-10-18 00:06:59,895] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 91)
#   2%|▏         | 21/1000 [00:02<01:36, 10.15it/s][2024-10-18 00:06:59,998] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 97, 122)
# [2024-10-18 00:07:00,095] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 102, 122)
#   2%|▏         | 23/1000 [00:02<01:37,  9.97it/s][2024-10-18 00:07:00,211] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 88, 99)
# [2024-10-18 00:07:00,321] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 81)
#   2%|▎         | 25/1000 [00:02<01:40,  9.66it/s][2024-10-18 00:07:00,427] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 67)
# [2024-10-18 00:07:00,459] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 193, 122)
#   3%|▎         | 27/1000 [00:02<01:32, 10.51it/s][2024-10-18 00:07:00,583] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 20, 51)
# [2024-10-18 00:07:00,707] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 78, 42)
#   3%|▎         | 29/1000 [00:02<01:40,  9.65it/s][2024-10-18 00:07:00,830] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 68)
# [2024-10-18 00:07:00,909] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 32)
#   3%|▎         | 31/1000 [00:03<01:38,  9.80it/s][2024-10-18 00:07:01,022] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 29)
# [2024-10-18 00:07:01,170] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 42, 63)
#   3%|▎         | 33/1000 [00:03<01:43,  9.34it/s][2024-10-18 00:07:01,263] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 31, 74)
# [2024-10-18 00:07:01,346] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 46)
#   4%|▎         | 35/1000 [00:03<01:41,  9.47it/s][2024-10-18 00:07:01,466] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 40)
# [2024-10-18 00:07:01,558] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 53)
#   4%|▎         | 37/1000 [00:03<01:28, 10.85it/s][2024-10-18 00:07:01,591] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 45)
# [2024-10-18 00:07:01,672] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 41)
#   4%|▍         | 39/1000 [00:03<01:25, 11.18it/s][2024-10-18 00:07:01,756] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 101, 99)
# [2024-10-18 00:07:01,847] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 24, 47)
#   4%|▍         | 41/1000 [00:04<01:26, 11.10it/s][2024-10-18 00:07:01,940] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 42)
# [2024-10-18 00:07:02,009] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 88, 69)
#   4%|▍         | 43/1000 [00:04<01:27, 10.99it/s][2024-10-18 00:07:02,121] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 53)
# [2024-10-18 00:07:02,222] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 26)
#   4%|▍         | 45/1000 [00:04<01:32, 10.33it/s][2024-10-18 00:07:02,342] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 55)
# [2024-10-18 00:07:02,430] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 50)
#   5%|▍         | 47/1000 [00:04<01:29, 10.62it/s][2024-10-18 00:07:02,523] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 35)
# [2024-10-18 00:07:02,619] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 74, 52)
#   5%|▍         | 49/1000 [00:04<01:33, 10.22it/s][2024-10-18 00:07:02,731] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 76)
# [2024-10-18 00:07:02,820] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 23, 64)
#   5%|▌         | 51/1000 [00:04<01:31, 10.37it/s][2024-10-18 00:07:02,917] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 35)
# [2024-10-18 00:07:03,002] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 20, 50)
#   5%|▌         | 53/1000 [00:05<01:27, 10.85it/s][2024-10-18 00:07:03,083] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 55)
# [2024-10-18 00:07:03,186] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 23, 41)
#   6%|▌         | 55/1000 [00:05<01:37,  9.68it/s][2024-10-18 00:07:03,346] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 43)
# [2024-10-18 00:07:03,432] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 63)
#   6%|▌         | 57/1000 [00:05<01:34, 10.02it/s][2024-10-18 00:07:03,529] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 32, 55)
# [2024-10-18 00:07:03,618] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 19, 52)
#   6%|▌         | 59/1000 [00:05<01:33, 10.09it/s][2024-10-18 00:07:03,720] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 47)
# [2024-10-18 00:07:03,727] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 39)
# [2024-10-18 00:07:03,796] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 80, 54)
#   6%|▌         | 62/1000 [00:05<01:17, 12.07it/s][2024-10-18 00:07:03,892] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 46)
# [2024-10-18 00:07:03,997] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 71)
#   6%|▋         | 64/1000 [00:06<01:26, 10.87it/s][2024-10-18 00:07:04,126] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 27)
# [2024-10-18 00:07:04,152] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 60, 78)
#   7%|▋         | 66/1000 [00:06<01:19, 11.80it/s][2024-10-18 00:07:04,261] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 63)
# [2024-10-18 00:07:04,366] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 49)
#   7%|▋         | 68/1000 [00:06<01:21, 11.39it/s][2024-10-18 00:07:04,449] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 43)
# [2024-10-18 00:07:04,528] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 68)
#   7%|▋         | 70/1000 [00:06<01:19, 11.67it/s][2024-10-18 00:07:04,612] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 31)
# [2024-10-18 00:07:04,703] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 25)
#   7%|▋         | 72/1000 [00:06<01:20, 11.52it/s][2024-10-18 00:07:04,788] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 54)
# [2024-10-18 00:07:04,869] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 32, 27)
# [2024-10-18 00:07:04,888] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 40)
#   8%|▊         | 75/1000 [00:07<01:16, 12.07it/s][2024-10-18 00:07:05,019] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 107, 79)
# [2024-10-18 00:07:05,121] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 64, 47)
#   8%|▊         | 77/1000 [00:07<01:21, 11.32it/s][2024-10-18 00:07:05,227] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 44)
# [2024-10-18 00:07:05,316] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 23, 49)
#   8%|▊         | 79/1000 [00:07<01:28, 10.42it/s][2024-10-18 00:07:05,461] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 24)
# [2024-10-18 00:07:05,545] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 26)
#   8%|▊         | 81/1000 [00:07<01:30, 10.18it/s][2024-10-18 00:07:05,665] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 41)
# [2024-10-18 00:07:05,748] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 93, 76)
#   8%|▊         | 83/1000 [00:07<01:27, 10.47it/s][2024-10-18 00:07:05,846] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 42, 55)
# [2024-10-18 00:07:05,925] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 25)
#   8%|▊         | 85/1000 [00:08<01:23, 10.95it/s][2024-10-18 00:07:06,008] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 38)
# [2024-10-18 00:07:06,113] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 58)
#   9%|▊         | 87/1000 [00:08<01:25, 10.72it/s][2024-10-18 00:07:06,202] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 26, 51)
# [2024-10-18 00:07:06,309] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 18)
#   9%|▉         | 89/1000 [00:08<01:21, 11.12it/s][2024-10-18 00:07:06,367] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 61)
# [2024-10-18 00:07:06,467] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 26)
#   9%|▉         | 91/1000 [00:08<01:26, 10.53it/s][2024-10-18 00:07:06,582] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 44)
# [2024-10-18 00:07:06,656] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 54, 76)
#   9%|▉         | 93/1000 [00:08<01:24, 10.73it/s][2024-10-18 00:07:06,757] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 76)
# [2024-10-18 00:07:06,832] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 106, 61)
#  10%|▉         | 95/1000 [00:08<01:21, 11.13it/s][2024-10-18 00:07:06,921] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 64)
# [2024-10-18 00:07:07,018] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 46)
#  10%|▉         | 97/1000 [00:09<01:21, 11.03it/s][2024-10-18 00:07:07,106] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 51)
# [2024-10-18 00:07:07,218] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 54)
#  10%|▉         | 99/1000 [00:09<01:25, 10.56it/s][2024-10-18 00:07:07,312] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 51)
# [2024-10-18 00:07:07,398] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 99)
# [2024-10-18 00:07:07,404] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 39)
#  10%|█         | 102/1000 [00:09<01:04, 13.97it/s][2024-10-18 00:07:07,419] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 75)
# [2024-10-18 00:07:07,496] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 105, 64)
#  10%|█         | 104/1000 [00:09<01:14, 12.10it/s][2024-10-18 00:07:07,644] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 80, 97)
# [2024-10-18 00:07:07,740] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 44)
#  11%|█         | 106/1000 [00:09<01:19, 11.25it/s][2024-10-18 00:07:07,854] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 49)
# [2024-10-18 00:07:07,981] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 79)
#  11%|█         | 108/1000 [00:10<01:20, 11.11it/s][2024-10-18 00:07:08,041] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 73, 78)
# [2024-10-18 00:07:08,138] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 43)
#  11%|█         | 110/1000 [00:10<01:10, 12.56it/s][2024-10-18 00:07:08,147] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 29)
# [2024-10-18 00:07:08,239] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 49)
#  11%|█         | 112/1000 [00:10<01:14, 11.91it/s][2024-10-18 00:07:08,342] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 64, 81)
# [2024-10-18 00:07:08,434] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 64)
#  11%|█▏        | 114/1000 [00:10<01:14, 11.89it/s][2024-10-18 00:07:08,510] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 46)
# [2024-10-18 00:07:08,533] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 77)
#  12%|█▏        | 116/1000 [00:10<01:14, 11.89it/s][2024-10-18 00:07:08,675] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 33)
# [2024-10-18 00:07:08,777] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 56)
#  12%|█▏        | 118/1000 [00:10<01:18, 11.30it/s][2024-10-18 00:07:08,871] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 20, 42)
# [2024-10-18 00:07:08,956] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 37)
#  12%|█▏        | 120/1000 [00:11<01:17, 11.38it/s][2024-10-18 00:07:09,047] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 151, 56)
# [2024-10-18 00:07:09,172] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 72, 84)
#  12%|█▏        | 122/1000 [00:11<01:21, 10.78it/s][2024-10-18 00:07:09,258] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 129, 100)
# [2024-10-18 00:07:09,384] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 128, 100)
#  12%|█▏        | 124/1000 [00:11<01:30,  9.73it/s][2024-10-18 00:07:09,508] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 85, 100)
# [2024-10-18 00:07:09,604] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 72, 137)
#  13%|█▎        | 126/1000 [00:11<01:34,  9.29it/s][2024-10-18 00:07:09,749] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 116, 47)
#  13%|█▎        | 127/1000 [00:11<01:39,  8.76it/s][2024-10-18 00:07:09,888] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 116, 169)
# [2024-10-18 00:07:09,977] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 82, 180)
#  13%|█▎        | 129/1000 [00:12<01:31,  9.54it/s][2024-10-18 00:07:10,061] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 72, 76)
# [2024-10-18 00:07:10,151] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 25, 54)
#  13%|█▎        | 131/1000 [00:12<01:27,  9.94it/s][2024-10-18 00:07:10,244] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 62)
# [2024-10-18 00:07:10,315] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 23)
#  13%|█▎        | 133/1000 [00:12<01:20, 10.77it/s][2024-10-18 00:07:10,400] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 70, 84)
# [2024-10-18 00:07:10,505] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 84, 56)
#  14%|█▎        | 135/1000 [00:12<01:22, 10.48it/s][2024-10-18 00:07:10,602] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 80, 90)
# [2024-10-18 00:07:10,640] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 85)
#  14%|█▎        | 137/1000 [00:12<01:11, 12.03it/s][2024-10-18 00:07:10,715] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 37)
# [2024-10-18 00:07:10,843] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 43)
#  14%|█▍        | 139/1000 [00:12<01:16, 11.24it/s][2024-10-18 00:07:10,919] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 51)
# [2024-10-18 00:07:10,995] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 32, 53)
#  14%|█▍        | 141/1000 [00:13<01:15, 11.40it/s][2024-10-18 00:07:11,085] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 33)
# [2024-10-18 00:07:11,172] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 31, 44)
#  14%|█▍        | 143/1000 [00:13<01:13, 11.59it/s][2024-10-18 00:07:11,252] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 42)
# [2024-10-18 00:07:11,298] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 57, 66)
#  14%|█▍        | 145/1000 [00:13<01:04, 13.23it/s][2024-10-18 00:07:11,354] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 89, 67)
# [2024-10-18 00:07:11,437] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 78)
#  15%|█▍        | 147/1000 [00:13<01:06, 12.89it/s][2024-10-18 00:07:11,516] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 26)
# [2024-10-18 00:07:11,600] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 38)
#  15%|█▍        | 149/1000 [00:13<01:09, 12.32it/s][2024-10-18 00:07:11,695] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 25, 46)
# [2024-10-18 00:07:11,770] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 18, 59)
#  15%|█▌        | 151/1000 [00:13<01:06, 12.74it/s][2024-10-18 00:07:11,840] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 72, 90)
# [2024-10-18 00:07:12,000] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 78, 52)
#  15%|█▌        | 153/1000 [00:14<01:25,  9.94it/s][2024-10-18 00:07:12,149] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 54, 39)
# [2024-10-18 00:07:12,251] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 34, 52)
#  16%|█▌        | 155/1000 [00:14<01:25,  9.84it/s][2024-10-18 00:07:12,356] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 59)
# [2024-10-18 00:07:12,444] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 32, 59)
#  16%|█▌        | 157/1000 [00:14<01:22, 10.20it/s][2024-10-18 00:07:12,531] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 54, 63)
# [2024-10-18 00:07:12,630] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 82, 59)
#  16%|█▌        | 159/1000 [00:14<01:19, 10.59it/s][2024-10-18 00:07:12,704] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 44)
# [2024-10-18 00:07:12,827] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 27)
#  16%|█▌        | 161/1000 [00:14<01:20, 10.46it/s][2024-10-18 00:07:12,905] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 45)
# [2024-10-18 00:07:13,031] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 42)
#  16%|█▋        | 163/1000 [00:15<01:24,  9.91it/s][2024-10-18 00:07:13,126] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 34)
# [2024-10-18 00:07:13,219] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 74)
#  16%|█▋        | 165/1000 [00:15<01:23, 10.06it/s][2024-10-18 00:07:13,323] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 42, 30)
# [2024-10-18 00:07:13,421] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 59, 42)
#  17%|█▋        | 167/1000 [00:15<01:21, 10.25it/s][2024-10-18 00:07:13,507] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 76)
# [2024-10-18 00:07:13,642] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 21)
#  17%|█▋        | 169/1000 [00:15<01:30,  9.18it/s][2024-10-18 00:07:13,780] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 36)
# [2024-10-18 00:07:13,857] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 44)
#  17%|█▋        | 171/1000 [00:16<01:29,  9.29it/s][2024-10-18 00:07:13,990] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 50)
# [2024-10-18 00:07:14,080] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 43)
#  17%|█▋        | 173/1000 [00:16<01:25,  9.71it/s][2024-10-18 00:07:14,174] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 46)
#  17%|█▋        | 174/1000 [00:16<01:25,  9.64it/s][2024-10-18 00:07:14,277] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 18)
# [2024-10-18 00:07:14,365] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 22)
#  18%|█▊        | 176/1000 [00:16<01:25,  9.66it/s][2024-10-18 00:07:14,482] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 71)
#  18%|█▊        | 177/1000 [00:16<01:25,  9.63it/s][2024-10-18 00:07:14,593] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 50)
# [2024-10-18 00:07:14,681] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 69, 71)
#  18%|█▊        | 179/1000 [00:16<01:22,  9.96it/s][2024-10-18 00:07:14,776] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 26)
# [2024-10-18 00:07:14,860] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 119, 122)
#  18%|█▊        | 181/1000 [00:17<01:18, 10.49it/s][2024-10-18 00:07:14,947] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 83, 86)
# [2024-10-18 00:07:15,027] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 206, 122)
#  18%|█▊        | 183/1000 [00:17<01:23,  9.82it/s][2024-10-18 00:07:15,183] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 57, 73)
#  18%|█▊        | 184/1000 [00:17<01:23,  9.82it/s][2024-10-18 00:07:15,284] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 85)
# [2024-10-18 00:07:15,363] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 163, 145)
#  19%|█▊        | 186/1000 [00:17<01:17, 10.53it/s][2024-10-18 00:07:15,446] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 31, 34)
# [2024-10-18 00:07:15,524] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 109)
#  19%|█▉        | 188/1000 [00:17<01:11, 11.29it/s][2024-10-18 00:07:15,595] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 42)
# [2024-10-18 00:07:15,678] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 25)
#  19%|█▉        | 190/1000 [00:17<01:09, 11.58it/s][2024-10-18 00:07:15,759] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 56)
# [2024-10-18 00:07:15,852] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 64)
#  19%|█▉        | 192/1000 [00:18<01:11, 11.36it/s][2024-10-18 00:07:15,944] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 73, 31)
# [2024-10-18 00:07:16,032] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 57, 64)
#  19%|█▉        | 194/1000 [00:18<01:06, 12.08it/s][2024-10-18 00:07:16,084] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 96, 67)
# [2024-10-18 00:07:16,094] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 81, 88)
# [2024-10-18 00:07:16,118] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 84, 100)
#  20%|█▉        | 197/1000 [00:18<00:50, 15.77it/s][2024-10-18 00:07:16,191] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 48)
# [2024-10-18 00:07:16,290] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 82, 94)
#  20%|█▉        | 199/1000 [00:18<00:58, 13.80it/s][2024-10-18 00:07:16,381] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 25, 43)
# [2024-10-18 00:07:16,501] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 64)
#  20%|██        | 201/1000 [00:18<01:06, 11.96it/s][2024-10-18 00:07:16,608] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 60)
# [2024-10-18 00:07:16,691] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 40)
#  20%|██        | 203/1000 [00:18<01:06, 11.94it/s][2024-10-18 00:07:16,772] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 52)
# [2024-10-18 00:07:16,870] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 144, 66)
#  20%|██        | 205/1000 [00:19<01:08, 11.57it/s][2024-10-18 00:07:16,961] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 73)
# [2024-10-18 00:07:17,047] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 31)
#  21%|██        | 207/1000 [00:19<01:08, 11.66it/s][2024-10-18 00:07:17,129] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 63)
# [2024-10-18 00:07:17,177] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 71)
#  21%|██        | 209/1000 [00:19<01:08, 11.60it/s][2024-10-18 00:07:17,303] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 56)
# [2024-10-18 00:07:17,383] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 79, 59)
#  21%|██        | 211/1000 [00:19<01:15, 10.47it/s][2024-10-18 00:07:17,536] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 53)
# [2024-10-18 00:07:17,631] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 52)
#  21%|██▏       | 213/1000 [00:19<01:14, 10.55it/s][2024-10-18 00:07:17,724] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 117)
# [2024-10-18 00:07:17,806] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 26, 33)
#  22%|██▏       | 215/1000 [00:20<01:17, 10.12it/s][2024-10-18 00:07:17,943] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 93)
# [2024-10-18 00:07:18,023] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 226, 127)
#  22%|██▏       | 217/1000 [00:20<01:14, 10.50it/s][2024-10-18 00:07:18,112] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 53)
# [2024-10-18 00:07:18,204] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 83, 125)
#  22%|██▏       | 219/1000 [00:20<01:10, 11.08it/s][2024-10-18 00:07:18,269] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 83, 32)
# [2024-10-18 00:07:18,301] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 33)
# [2024-10-18 00:07:18,350] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 52)
#  22%|██▏       | 222/1000 [00:20<01:00, 12.84it/s][2024-10-18 00:07:18,445] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 136, 70)
# [2024-10-18 00:07:18,523] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 39)
#  22%|██▏       | 224/1000 [00:20<01:00, 12.87it/s][2024-10-18 00:07:18,599] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 53)
# [2024-10-18 00:07:18,675] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 104, 99)
#  23%|██▎       | 226/1000 [00:20<01:01, 12.65it/s][2024-10-18 00:07:18,764] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 99)
# [2024-10-18 00:07:18,867] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 48)
#  23%|██▎       | 228/1000 [00:21<01:06, 11.60it/s][2024-10-18 00:07:18,974] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 36)
# [2024-10-18 00:07:19,076] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 85)
#  23%|██▎       | 230/1000 [00:21<01:08, 11.27it/s][2024-10-18 00:07:19,168] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 69, 89)
# [2024-10-18 00:07:19,259] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 38)
#  23%|██▎       | 232/1000 [00:21<01:07, 11.41it/s][2024-10-18 00:07:19,337] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 59)
# [2024-10-18 00:07:19,393] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 25)
#  23%|██▎       | 234/1000 [00:21<01:02, 12.19it/s][2024-10-18 00:07:19,475] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 25)
# [2024-10-18 00:07:19,595] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 48)
#  24%|██▎       | 236/1000 [00:21<01:08, 11.11it/s][2024-10-18 00:07:19,688] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 75)
# [2024-10-18 00:07:19,781] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 122, 90)
#  24%|██▍       | 238/1000 [00:21<01:10, 10.88it/s][2024-10-18 00:07:19,885] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 86, 117)
# [2024-10-18 00:07:19,955] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 24, 90)
#  24%|██▍       | 240/1000 [00:22<01:07, 11.30it/s][2024-10-18 00:07:20,042] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 71, 48)
# [2024-10-18 00:07:20,153] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 79)
#  24%|██▍       | 242/1000 [00:22<01:09, 10.97it/s][2024-10-18 00:07:20,236] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 96, 115)
# [2024-10-18 00:07:20,338] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 39)
#  24%|██▍       | 244/1000 [00:22<01:10, 10.76it/s][2024-10-18 00:07:20,435] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 47)
# [2024-10-18 00:07:20,458] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 101, 67)
# [2024-10-18 00:07:20,506] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 83, 120)
#  25%|██▍       | 247/1000 [00:22<01:00, 12.47it/s][2024-10-18 00:07:20,614] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 83, 47)
# [2024-10-18 00:07:20,694] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 73, 85)
#  25%|██▍       | 249/1000 [00:22<01:01, 12.27it/s][2024-10-18 00:07:20,781] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 40)
# [2024-10-18 00:07:20,883] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 34, 67)
#  25%|██▌       | 251/1000 [00:23<01:03, 11.72it/s][2024-10-18 00:07:20,977] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 52)
# [2024-10-18 00:07:21,067] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 71, 58)
#  25%|██▌       | 253/1000 [00:23<01:05, 11.40it/s][2024-10-18 00:07:21,163] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 37)
# [2024-10-18 00:07:21,242] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 52)
#  26%|██▌       | 255/1000 [00:23<01:04, 11.49it/s][2024-10-18 00:07:21,330] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 26, 50)
# [2024-10-18 00:07:21,406] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 58)
#  26%|██▌       | 257/1000 [00:23<01:07, 11.04it/s][2024-10-18 00:07:21,528] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 24)
# [2024-10-18 00:07:21,659] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 104, 58)
#  26%|██▌       | 259/1000 [00:23<01:17,  9.58it/s][2024-10-18 00:07:21,807] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 156, 114)
#  26%|██▌       | 260/1000 [00:24<01:22,  9.02it/s][2024-10-18 00:07:21,948] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 58)
#  26%|██▌       | 261/1000 [00:24<01:20,  9.18it/s][2024-10-18 00:07:22,049] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 49)
# [2024-10-18 00:07:22,138] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 198, 141)
#  26%|██▋       | 263/1000 [00:24<01:11, 10.24it/s][2024-10-18 00:07:22,202] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 201, 139)
# [2024-10-18 00:07:22,310] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 69, 141)
#  26%|██▋       | 265/1000 [00:24<01:13, 10.06it/s][2024-10-18 00:07:22,412] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 147, 121)
# [2024-10-18 00:07:22,522] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 391, 140)
#  27%|██▋       | 267/1000 [00:24<01:15,  9.69it/s][2024-10-18 00:07:22,632] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 109, 154)
# [2024-10-18 00:07:22,708] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 138, 141)
#  27%|██▋       | 269/1000 [00:24<01:11, 10.16it/s][2024-10-18 00:07:22,809] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 137, 95)
# [2024-10-18 00:07:22,896] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 98, 53)
#  27%|██▋       | 271/1000 [00:25<01:13,  9.87it/s][2024-10-18 00:07:23,026] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 145, 61)
# [2024-10-18 00:07:23,111] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 139)
#  27%|██▋       | 273/1000 [00:25<01:11, 10.24it/s][2024-10-18 00:07:23,204] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 58)
# [2024-10-18 00:07:23,273] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 54)
#  28%|██▊       | 275/1000 [00:25<01:03, 11.39it/s][2024-10-18 00:07:23,336] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 45)
# [2024-10-18 00:07:23,440] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 96, 146)
#  28%|██▊       | 277/1000 [00:25<01:07, 10.77it/s][2024-10-18 00:07:23,544] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 40)
# [2024-10-18 00:07:23,634] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 42)
#  28%|██▊       | 279/1000 [00:25<01:06, 10.92it/s][2024-10-18 00:07:23,717] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 37)
# [2024-10-18 00:07:23,808] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 18)
#  28%|██▊       | 281/1000 [00:25<01:05, 10.93it/s][2024-10-18 00:07:23,900] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 123)
# [2024-10-18 00:07:23,992] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 63, 18)
#  28%|██▊       | 283/1000 [00:26<01:05, 10.98it/s][2024-10-18 00:07:24,085] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 70)
# [2024-10-18 00:07:24,165] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 169, 116)
#  28%|██▊       | 285/1000 [00:26<01:06, 10.77it/s][2024-10-18 00:07:24,277] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 128)
# [2024-10-18 00:07:24,368] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 101, 52)
#  29%|██▊       | 287/1000 [00:26<01:09, 10.30it/s][2024-10-18 00:07:24,493] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 49)
# [2024-10-18 00:07:24,576] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 16)
#  29%|██▉       | 289/1000 [00:26<01:07, 10.52it/s][2024-10-18 00:07:24,673] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 101)
# [2024-10-18 00:07:24,773] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 52)
#  29%|██▉       | 291/1000 [00:26<01:07, 10.44it/s][2024-10-18 00:07:24,863] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 137, 54)
# [2024-10-18 00:07:24,971] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 43, 42)
#  29%|██▉       | 293/1000 [00:27<01:10, 10.04it/s][2024-10-18 00:07:25,080] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 42, 61)
# [2024-10-18 00:07:25,179] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 98, 68)
#  30%|██▉       | 295/1000 [00:27<01:11,  9.85it/s][2024-10-18 00:07:25,294] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 33)
# [2024-10-18 00:07:25,386] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 48)
#  30%|██▉       | 297/1000 [00:27<01:11,  9.84it/s][2024-10-18 00:07:25,501] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 39, 38)
#  30%|██▉       | 298/1000 [00:27<01:12,  9.74it/s][2024-10-18 00:07:25,609] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 55)
# [2024-10-18 00:07:25,697] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 63, 71)
#  30%|███       | 300/1000 [00:27<01:11,  9.79it/s][2024-10-18 00:07:25,808] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 35)
# [2024-10-18 00:07:25,883] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 31, 48)
#  30%|███       | 302/1000 [00:28<01:10,  9.87it/s][2024-10-18 00:07:26,012] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 26, 46)
#  30%|███       | 303/1000 [00:28<01:15,  9.17it/s][2024-10-18 00:07:26,152] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 111)
#  30%|███       | 304/1000 [00:28<01:17,  8.96it/s][2024-10-18 00:07:26,269] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 98, 140)
#  30%|███       | 305/1000 [00:28<01:16,  9.13it/s][2024-10-18 00:07:26,371] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 189, 144)
#  31%|███       | 306/1000 [00:28<01:15,  9.16it/s][2024-10-18 00:07:26,483] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 95)
# [2024-10-18 00:07:26,575] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 121, 54)
#  31%|███       | 308/1000 [00:28<01:08, 10.16it/s][2024-10-18 00:07:26,647] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 127, 83)
# [2024-10-18 00:07:26,662] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 49)
#  31%|███       | 310/1000 [00:28<00:56, 12.24it/s][2024-10-18 00:07:26,756] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 31)
# [2024-10-18 00:07:26,831] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 82)
#  31%|███       | 312/1000 [00:28<00:56, 12.22it/s][2024-10-18 00:07:26,917] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 113, 83)
# [2024-10-18 00:07:26,997] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 28, 34)
#  31%|███▏      | 314/1000 [00:29<00:55, 12.33it/s][2024-10-18 00:07:27,077] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 34)
# [2024-10-18 00:07:27,213] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 97, 34)
#  32%|███▏      | 316/1000 [00:29<01:05, 10.50it/s][2024-10-18 00:07:27,331] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 114, 114)
# [2024-10-18 00:07:27,425] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 60, 114)
#  32%|███▏      | 318/1000 [00:29<01:04, 10.53it/s][2024-10-18 00:07:27,519] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 63, 30)
# [2024-10-18 00:07:27,604] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 82)
#  32%|███▏      | 320/1000 [00:29<01:04, 10.59it/s][2024-10-18 00:07:27,704] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 33)
# [2024-10-18 00:07:27,811] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 33)
#  32%|███▏      | 322/1000 [00:29<01:04, 10.44it/s][2024-10-18 00:07:27,900] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 53)
# [2024-10-18 00:07:27,989] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 31)
#  32%|███▏      | 324/1000 [00:30<01:04, 10.51it/s][2024-10-18 00:07:28,090] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 88, 152)
# [2024-10-18 00:07:28,144] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 88, 53)
#  33%|███▎      | 326/1000 [00:30<01:05, 10.32it/s][2024-10-18 00:07:28,290] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 71)
# [2024-10-18 00:07:28,410] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 113, 96)
#  33%|███▎      | 328/1000 [00:30<01:05, 10.21it/s][2024-10-18 00:07:28,495] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 73)
# [2024-10-18 00:07:28,579] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 102, 66)
#  33%|███▎      | 330/1000 [00:30<01:04, 10.35it/s][2024-10-18 00:07:28,680] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 118)
# [2024-10-18 00:07:28,767] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 37)
#  33%|███▎      | 332/1000 [00:30<01:02, 10.63it/s][2024-10-18 00:07:28,858] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 21, 49)
# [2024-10-18 00:07:28,947] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 105, 104)
#  33%|███▎      | 334/1000 [00:31<01:01, 10.85it/s][2024-10-18 00:07:29,032] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 24, 50)
# [2024-10-18 00:07:29,123] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 59)
#  34%|███▎      | 336/1000 [00:31<00:58, 11.34it/s][2024-10-18 00:07:29,186] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 63)
# [2024-10-18 00:07:29,308] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 50)
#  34%|███▍      | 338/1000 [00:31<01:02, 10.58it/s][2024-10-18 00:07:29,405] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 22, 46)
# [2024-10-18 00:07:29,505] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 75)
#  34%|███▍      | 340/1000 [00:31<01:04, 10.22it/s][2024-10-18 00:07:29,616] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 26)
# [2024-10-18 00:07:29,704] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 38)
#  34%|███▍      | 342/1000 [00:31<01:02, 10.52it/s][2024-10-18 00:07:29,798] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 73, 78)
# [2024-10-18 00:07:29,885] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 108)
#  34%|███▍      | 344/1000 [00:32<01:01, 10.72it/s][2024-10-18 00:07:29,972] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 58)
# [2024-10-18 00:07:30,059] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 55)
#  35%|███▍      | 346/1000 [00:32<00:59, 11.04it/s][2024-10-18 00:07:30,144] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 26, 75)
# [2024-10-18 00:07:30,248] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 172, 183)
#  35%|███▍      | 348/1000 [00:32<01:05, 10.01it/s][2024-10-18 00:07:30,388] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 26)
# [2024-10-18 00:07:30,509] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 50, 21)
#  35%|███▌      | 350/1000 [00:32<01:06,  9.74it/s][2024-10-18 00:07:30,605] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 84)
#  35%|███▌      | 351/1000 [00:32<01:06,  9.71it/s][2024-10-18 00:07:30,707] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 36)
#  35%|███▌      | 352/1000 [00:32<01:06,  9.69it/s][2024-10-18 00:07:30,810] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 72)
# [2024-10-18 00:07:30,898] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 97)
#  35%|███▌      | 354/1000 [00:33<00:58, 11.10it/s][2024-10-18 00:07:30,950] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 24)
# [2024-10-18 00:07:31,036] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 31)
#  36%|███▌      | 356/1000 [00:33<01:00, 10.73it/s][2024-10-18 00:07:31,144] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 45)
# [2024-10-18 00:07:31,239] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 43)
#  36%|███▌      | 358/1000 [00:33<00:59, 10.80it/s][2024-10-18 00:07:31,327] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 49)
# [2024-10-18 00:07:31,381] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 40, 41)
#  36%|███▌      | 360/1000 [00:33<00:54, 11.75it/s][2024-10-18 00:07:31,467] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 44)
# [2024-10-18 00:07:31,585] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 42, 27)
#  36%|███▌      | 362/1000 [00:33<00:59, 10.72it/s][2024-10-18 00:07:31,691] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 38)
# [2024-10-18 00:07:31,819] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 78)
# ...
#  88%|████████▊ | 880/1000 [01:23<00:11, 10.19it/s][2024-10-18 00:08:21,354] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 95, 103)
# [2024-10-18 00:08:21,433] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 63)
#  88%|████████▊ | 882/1000 [01:23<00:10, 10.77it/s][2024-10-18 00:08:21,519] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 61, 35)
# [2024-10-18 00:08:21,639] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 59, 21)
#  88%|████████▊ | 884/1000 [01:23<00:11, 10.37it/s][2024-10-18 00:08:21,725] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 75, 32)
# [2024-10-18 00:08:21,841] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 36)
#  89%|████████▊ | 886/1000 [01:23<00:11, 10.17it/s][2024-10-18 00:08:21,933] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 85, 42)
# [2024-10-18 00:08:22,034] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 49)
#  89%|████████▉ | 888/1000 [01:24<00:10, 10.20it/s][2024-10-18 00:08:22,128] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 27, 45)
# [2024-10-18 00:08:22,237] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 76)
#  89%|████████▉ | 890/1000 [01:24<00:11,  9.99it/s][2024-10-18 00:08:22,337] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 23, 38)
# [2024-10-18 00:08:22,455] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 50)
#  89%|████████▉ | 892/1000 [01:24<00:10,  9.96it/s][2024-10-18 00:08:22,536] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 16)
# [2024-10-18 00:08:22,611] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 67, 47)
#  89%|████████▉ | 894/1000 [01:24<00:09, 10.81it/s][2024-10-18 00:08:22,684] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 33)
# [2024-10-18 00:08:22,774] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 60, 24)
#  90%|████████▉ | 896/1000 [01:24<00:10,  9.96it/s][2024-10-18 00:08:22,923] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 17, 52)
# [2024-10-18 00:08:23,026] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 119)
#  90%|████████▉ | 898/1000 [01:25<00:10,  9.70it/s][2024-10-18 00:08:23,140] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 101, 141)
#  90%|████████▉ | 899/1000 [01:25<00:10,  9.72it/s][2024-10-18 00:08:23,247] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 34)
#  90%|█████████ | 900/1000 [01:25<00:10,  9.42it/s][2024-10-18 00:08:23,362] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 147, 125)
#  90%|█████████ | 901/1000 [01:25<00:10,  9.25it/s][2024-10-18 00:08:23,480] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 114, 73)
# [2024-10-18 00:08:23,565] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 108, 146)
#  90%|█████████ | 903/1000 [01:25<00:09, 10.03it/s][2024-10-18 00:08:23,650] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 101, 76)
# [2024-10-18 00:08:23,729] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 57, 51)
#  90%|█████████ | 905/1000 [01:25<00:09, 10.44it/s][2024-10-18 00:08:23,828] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 20, 104)
# [2024-10-18 00:08:23,937] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 59)
#  91%|█████████ | 907/1000 [01:26<00:09, 10.18it/s][2024-10-18 00:08:24,037] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 58)
# [2024-10-18 00:08:24,123] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 24, 36)
#  91%|█████████ | 909/1000 [01:26<00:08, 10.28it/s][2024-10-18 00:08:24,227] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 78, 118)
# [2024-10-18 00:08:24,317] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 111, 130)
#  91%|█████████ | 911/1000 [01:26<00:08, 10.24it/s][2024-10-18 00:08:24,423] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 71, 96)
# [2024-10-18 00:08:24,527] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 45)
#  91%|█████████▏| 913/1000 [01:26<00:08,  9.95it/s][2024-10-18 00:08:24,638] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 48, 48)
# [2024-10-18 00:08:24,731] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 85, 35)
#  92%|█████████▏| 915/1000 [01:26<00:07, 11.10it/s][2024-10-18 00:08:24,772] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 33, 49)
# [2024-10-18 00:08:24,893] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 61)
#  92%|█████████▏| 917/1000 [01:27<00:08,  9.72it/s][2024-10-18 00:08:25,035] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 84, 132)
# [2024-10-18 00:08:25,142] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 118)
#  92%|█████████▏| 919/1000 [01:27<00:08,  9.57it/s][2024-10-18 00:08:25,248] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 46)
#  92%|█████████▏| 920/1000 [01:27<00:08,  9.28it/s][2024-10-18 00:08:25,370] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 121)
#  92%|█████████▏| 921/1000 [01:27<00:08,  9.23it/s][2024-10-18 00:08:25,482] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 53, 103)
# [2024-10-18 00:08:25,568] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 91)
#  92%|█████████▏| 923/1000 [01:27<00:07, 10.04it/s][2024-10-18 00:08:25,653] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 37)
# [2024-10-18 00:08:25,758] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 71, 142)
#  92%|█████████▎| 925/1000 [01:27<00:07, 10.15it/s][2024-10-18 00:08:25,844] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 53)
# [2024-10-18 00:08:25,939] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 29, 37)
#  93%|█████████▎| 927/1000 [01:28<00:07, 10.22it/s][2024-10-18 00:08:26,040] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 19)
# [2024-10-18 00:08:26,124] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 45, 37)
#  93%|█████████▎| 929/1000 [01:28<00:06, 10.60it/s][2024-10-18 00:08:26,216] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 156, 190)
# [2024-10-18 00:08:26,317] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 30, 35)
#  93%|█████████▎| 931/1000 [01:28<00:06, 10.47it/s][2024-10-18 00:08:26,409] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 70, 35)
# [2024-10-18 00:08:26,461] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 98, 71)
# [2024-10-18 00:08:26,488] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 56, 61)
#  93%|█████████▎| 934/1000 [01:28<00:05, 12.13it/s][2024-10-18 00:08:26,597] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 56)
# [2024-10-18 00:08:26,687] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 19, 47)
#  94%|█████████▎| 936/1000 [01:28<00:05, 11.82it/s][2024-10-18 00:08:26,778] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 70)
# [2024-10-18 00:08:26,885] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 82, 52)
#  94%|█████████▍| 938/1000 [01:29<00:05, 11.50it/s][2024-10-18 00:08:26,961] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 34)
# [2024-10-18 00:08:27,055] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 81, 47)
#  94%|█████████▍| 940/1000 [01:29<00:05, 10.47it/s][2024-10-18 00:08:27,200] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 85, 68)
# [2024-10-18 00:08:27,300] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 199, 164)
#  94%|█████████▍| 942/1000 [01:29<00:05, 10.34it/s][2024-10-18 00:08:27,400] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 30, 31)
# [2024-10-18 00:08:27,492] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 64, 40)
#  94%|█████████▍| 944/1000 [01:29<00:05, 10.82it/s][2024-10-18 00:08:27,558] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 76, 70)
# [2024-10-18 00:08:27,565] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 58, 98)
# [2024-10-18 00:08:27,589] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 112, 97)
#  95%|█████████▍| 947/1000 [01:29<00:03, 13.28it/s][2024-10-18 00:08:27,706] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 77, 36)
# [2024-10-18 00:08:27,812] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 46, 28)
#  95%|█████████▍| 949/1000 [01:29<00:04, 12.42it/s][2024-10-18 00:08:27,892] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 37)
# [2024-10-18 00:08:27,973] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 49, 36)
#  95%|█████████▌| 951/1000 [01:30<00:03, 12.31it/s][2024-10-18 00:08:28,059] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 35, 53)
# [2024-10-18 00:08:28,128] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 32, 30)
#  95%|█████████▌| 953/1000 [01:30<00:03, 12.05it/s][2024-10-18 00:08:28,233] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 71)
# [2024-10-18 00:08:28,326] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 78, 60)
#  96%|█████████▌| 955/1000 [01:30<00:03, 11.67it/s][2024-10-18 00:08:28,419] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 56)
# [2024-10-18 00:08:28,525] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 141, 171)
#  96%|█████████▌| 957/1000 [01:30<00:03, 10.83it/s][2024-10-18 00:08:28,637] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 93)
# [2024-10-18 00:08:28,733] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 71, 38)
#  96%|█████████▌| 959/1000 [01:30<00:03, 11.01it/s][2024-10-18 00:08:28,814] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 57, 77)
# [2024-10-18 00:08:28,908] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 34)
#  96%|█████████▌| 961/1000 [01:31<00:03, 10.78it/s][2024-10-18 00:08:29,003] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 87, 87)
# [2024-10-18 00:08:29,109] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 46)
#  96%|█████████▋| 963/1000 [01:31<00:03, 10.81it/s][2024-10-18 00:08:29,190] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 59, 65)
# [2024-10-18 00:08:29,310] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 84)
#  96%|█████████▋| 965/1000 [01:31<00:03,  9.95it/s][2024-10-18 00:08:29,428] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 37, 39)
# [2024-10-18 00:08:29,528] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 50)
#  97%|█████████▋| 967/1000 [01:31<00:03, 10.12it/s][2024-10-18 00:08:29,616] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 102, 128)
# [2024-10-18 00:08:29,705] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 49)
#  97%|█████████▋| 969/1000 [01:31<00:03, 10.24it/s][2024-10-18 00:08:29,811] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 82)
# [2024-10-18 00:08:29,896] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 91, 55)
#  97%|█████████▋| 971/1000 [01:32<00:02, 10.62it/s][2024-10-18 00:08:29,978] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 58)
# [2024-10-18 00:08:30,076] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 121, 86)
#  97%|█████████▋| 973/1000 [01:32<00:02, 10.71it/s][2024-10-18 00:08:30,161] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 102, 192)
# [2024-10-18 00:08:30,263] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 62, 53)
#  98%|█████████▊| 975/1000 [01:32<00:02, 10.18it/s][2024-10-18 00:08:30,384] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 89, 96)
# [2024-10-18 00:08:30,502] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 66, 60)
#  98%|█████████▊| 977/1000 [01:32<00:02,  9.86it/s][2024-10-18 00:08:30,598] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 109, 113)
# [2024-10-18 00:08:30,684] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 55, 20)
#  98%|█████████▊| 979/1000 [01:32<00:02, 10.03it/s][2024-10-18 00:08:30,794] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 60, 68)
# [2024-10-18 00:08:30,893] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 47, 42)
#  98%|█████████▊| 981/1000 [01:33<00:01, 10.12it/s][2024-10-18 00:08:30,987] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 65, 72)
# [2024-10-18 00:08:31,090] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 149, 168)
#  98%|█████████▊| 983/1000 [01:33<00:01,  9.95it/s][2024-10-18 00:08:31,196] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 38, 71)
# [2024-10-18 00:08:31,277] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 112, 99)
#  98%|█████████▊| 985/1000 [01:33<00:01,  9.60it/s][2024-10-18 00:08:31,417] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 36)
#  99%|█████████▊| 986/1000 [01:33<00:01,  9.32it/s][2024-10-18 00:08:31,545] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 59, 30)
#  99%|█████████▊| 987/1000 [01:33<00:01,  8.99it/s][2024-10-18 00:08:31,666] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 78, 86)
# [2024-10-18 00:08:31,754] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 175, 219)
#  99%|█████████▉| 989/1000 [01:33<00:01,  9.61it/s][2024-10-18 00:08:31,848] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 60, 98)
# [2024-10-18 00:08:31,945] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 22, 41)
#  99%|█████████▉| 991/1000 [01:34<00:00, 10.19it/s][2024-10-18 00:08:32,024] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 44, 56)
# [2024-10-18 00:08:32,128] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 51, 86)
#  99%|█████████▉| 993/1000 [01:34<00:00, 10.34it/s][2024-10-18 00:08:32,213] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 41, 42)
# [2024-10-18 00:08:32,299] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 119, 125)
# 100%|█████████▉| 995/1000 [01:34<00:00, 10.59it/s][2024-10-18 00:08:32,389] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 68, 71)
# [2024-10-18 00:08:32,490] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 113, 113)
# 100%|█████████▉| 997/1000 [01:34<00:00, 10.23it/s][2024-10-18 00:08:32,600] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 52, 58)
# [2024-10-18 00:08:32,697] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 36, 35)
# 100%|█████████▉| 999/1000 [01:34<00:00, 10.50it/s][2024-10-18 00:08:32,779] [INFO] src.model.constrastive_learning_utils: Size of pos proposal: (3, 90, 98)
# 100%|██████████| 1000/1000 [01:34<00:00, 10.53it/s]

# %%
from torch.utils.data import DataLoader, Dataset


train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, num_workers=4)
val_loader = DataLoader(val_dataset, batch_size=4, shuffle=True, num_workers=1)

# %%
# import matplotlib.pyplot as plt

# # Define the number of pairs to show at a time
# pairs_per_page = 5

# # Iterate over the specified range of pairs, in steps of `pairs_per_page`
# for i in range(20, 40, pairs_per_page):
#     # Create a new figure for each set of 5 pairs
#     plt.figure(figsize=(15, 10))  # Adjusted the figsize for multiple pairs

#     for j in range(pairs_per_page):
#         # Calculate the current pair index
#         pair_index = i + j

#         # Check if the pair_index is within the bounds of the list
#         if pair_index >= len(val_set):
#             break

#         pair = val_set[pair_index]

#         # First image in the pair (img2)
#         plt.subplot(pairs_per_page, 2, 2*j + 1)
#         plt.imshow(pair["pos"].permute(1, 2, 0))
#         plt.axis('off')

#         # Second image in the pair (img1)
#         plt.subplot(pairs_per_page, 2, 2*j + 2)
#         plt.imshow(pair["anchor"].permute(1, 2, 0))
#         plt.axis('off')

#     # Display the figure containing 5 pairs
#     plt.show()

# %%
# import matplotlib.pyplot as plt

# # Define the number of pairs to show at a time
# pairs_per_page = 5

# # Iterate over the specified range of pairs, in steps of `pairs_per_page`
# for i in range(20, 40, pairs_per_page):
#     # Create a new figure for each set of 5 pairs
#     plt.figure(figsize=(15, 10))  # Adjusted the figsize for multiple pairs

#     for j in range(pairs_per_page):
#         # Calculate the current pair index
#         pair_index = i + j

#         # Check if the pair_index is within the bounds of the list
#         if pair_index >= len(val_set):
#             break

#         pair = val_set[pair_index]

#         # First image in the pair (img2)
#         plt.subplot(pairs_per_page, 2, 2*j + 1)
#         plt.imshow(pair["neg"].permute(1, 2, 0))
#         plt.axis('off')

#         # Second image in the pair (img1)
#         plt.subplot(pairs_per_page, 2, 2*j + 2)
#         plt.imshow(pair["anchor"].permute(1, 2, 0))
#         plt.axis('off')

#     # Display the figure containing 5 pairs
#     plt.show()

# %%
# import matplotlib.pyplot as plt

# # Define the number of pairs to show at a time
# pairs_per_page = 5

# # Iterate over the specified range of pairs, in steps of `pairs_per_page`
# for i in range(20, 40, pairs_per_page):
#     # Create a new figure for each set of 5 pairs
#     plt.figure(figsize=(15, 10))  # Adjusted the figsize for multiple pairs

#     for j in range(pairs_per_page):
#         # Calculate the current pair index
#         pair_index = i + j

#         # Check if the pair_index is within the bounds of the list
#         if pair_index >= len(val_set):
#             break

#         pair = val_set[pair_index]

#         # First image in the pair (img2)
#         plt.subplot(pairs_per_page, 2, 2*j + 1)
#         plt.imshow(pair["neg"].permute(1, 2, 0))
#         plt.axis('off')

#         # Second image in the pair (img1)
#         plt.subplot(pairs_per_page, 2, 2*j + 2)
#         plt.imshow(pair["anchor"].permute(1, 2, 0))
#         plt.axis('off')

#     # Display the figure containing 5 pairs
#     plt.show()

# %%
# import matplotlib.pyplot as plt
# for pair in train_negative_pairs[:40]:
#     plt.figure(figsize=(10, 5))
#     plt.subplot(1, 2, 1)
#     plt.imshow(pair["img1"].permute(1,2,0))
#     plt.axis('off')

#     plt.subplot(1, 2, 2)
#     plt.imshow(pair["img2"].permute(1,2,0))
#     plt.axis('off')

#     plt.show()

# %%
from src.model.contrastive_learning_info_nce import train_info_nce_loss
dataset = "icbin"
train_info_nce_loss(device, model, train_loader, val_loader, num_epochs=15, dataset=dataset)
# train_contrastive_loss(device, model, train_dataset, val_dataset, test_dataset, num_epochs=25) # this time train_pbr
# Out:
# [2024-10-16 13:43:37,519] [ERROR] wandb.jupyter: Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: damvancuong510. Use `wandb login --relogin` to force relogin
# wandb version 0.18.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.17.6
# Run data is saved locally in <code>/home/cuong.van-dam/CuongVanDam/do_an_tot_nghiep/cnos/wandb/run-20241016_134338-lqf535yl</code>
# Syncing run <strong><a href='https://wandb.ai/damvancuong510/cnos_info_nce_loss/runs/lqf535yl' target="_blank">hopeful-bush-7</a></strong> to <a href='https://wandb.ai/damvancuong510/cnos_info_nce_loss' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/damvancuong510/cnos_info_nce_loss' target="_blank">https://wandb.ai/damvancuong510/cnos_info_nce_loss</a>
#  View run at <a href='https://wandb.ai/damvancuong510/cnos_info_nce_loss/runs/lqf535yl' target="_blank">https://wandb.ai/damvancuong510/cnos_info_nce_loss/runs/lqf535yl</a>
# Training:   0%|          | 0/15 [00:00<?, ?it/s]/home/cuong.van-dam/miniconda3/envs/cnos/lib/python3.9/site-packages/xformers/ops/unbind.py:46: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   storage_data_ptr = tensors[0].storage().data_ptr()
# /home/cuong.van-dam/miniconda3/envs/cnos/lib/python3.9/site-packages/xformers/ops/unbind.py:48: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   if x.storage().data_ptr() != storage_data_ptr:
# [2024-10-16 13:59:49,399] [INFO] src.model.contrastive_learning_info_nce: Epoch 1/15 loss: 0.53460
# [2024-10-16 14:00:36,453] [INFO] src.model.contrastive_learning_info_nce: Epoch 1/15 Validation Loss: 0.20457
# best_val_loss:  0.20457328046259743
# saving best model at epoch:  0
# Training:   7%|▋         | 1/15 [16:54<3:56:48, 1014.87s/it][2024-10-16 14:16:43,193] [INFO] src.model.contrastive_learning_info_nce: Epoch 2/15 loss: 0.41576
# Training:  13%|█▎        | 2/15 [33:00<3:33:39, 986.08s/it] [2024-10-16 14:32:48,807] [INFO] src.model.contrastive_learning_info_nce: Epoch 3/15 loss: 0.38269
# Training:  20%|██        | 3/15 [49:06<3:15:20, 976.73s/it][2024-10-16 14:48:55,523] [INFO] src.model.contrastive_learning_info_nce: Epoch 4/15 loss: 0.34101
# [2024-10-16 14:49:41,792] [INFO] src.model.contrastive_learning_info_nce: Epoch 4/15 Validation Loss: 0.20760
# Training:  27%|██▋       | 4/15 [1:05:59<3:01:41, 991.05s/it][2024-10-16 15:05:49,605] [INFO] src.model.contrastive_learning_info_nce: Epoch 5/15 loss: 0.34198
# Training:  33%|███▎      | 5/15 [1:22:07<2:43:46, 982.67s/it][2024-10-16 15:21:56,299] [INFO] src.model.contrastive_learning_info_nce: Epoch 6/15 loss: 0.35036
# Training:  40%|████      | 6/15 [1:38:14<2:26:37, 977.53s/it][2024-10-16 15:38:04,468] [INFO] src.model.contrastive_learning_info_nce: Epoch 7/15 loss: 0.30555
# [2024-10-16 15:38:50,748] [INFO] src.model.contrastive_learning_info_nce: Epoch 7/15 Validation Loss: 0.12424
# best_val_loss:  0.12424262591376949
# saving best model at epoch:  6
# Training:  47%|████▋     | 7/15 [1:55:10<2:12:01, 990.16s/it][2024-10-16 15:55:00,554] [INFO] src.model.contrastive_learning_info_nce: Epoch 8/15 loss: 0.31906
# Training:  53%|█████▎    | 8/15 [2:11:18<1:54:40, 982.86s/it][2024-10-16 16:11:07,339] [INFO] src.model.contrastive_learning_info_nce: Epoch 9/15 loss: 0.30877
# Training:  60%|██████    | 9/15 [2:27:24<1:37:47, 977.83s/it][2024-10-16 16:27:14,624] [INFO] src.model.contrastive_learning_info_nce: Epoch 10/15 loss: 0.30860
# [2024-10-16 16:28:00,816] [INFO] src.model.contrastive_learning_info_nce: Epoch 10/15 Validation Loss: 0.17098
# Training:  67%|██████▋   | 10/15 [2:44:18<1:22:24, 988.84s/it][2024-10-16 16:44:07,942] [INFO] src.model.contrastive_learning_info_nce: Epoch 11/15 loss: 0.29927
# Training:  73%|███████▎  | 11/15 [3:00:26<1:05:29, 982.44s/it][2024-10-16 17:00:15,695] [INFO] src.model.contrastive_learning_info_nce: Epoch 12/15 loss: 0.25662
# Training:  80%|████████  | 12/15 [3:27:25<51:51, 1037.12s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 from src.model.contrastive_learning_info_nce import train_info_nce_loss
#       2 dataset = "icbin"
# ----> 3 train_info_nce_loss(device, model, train_loader, val_loader, num_epochs=15, dataset=dataset)
#       4 # train_contrastive_loss(device, model, train_dataset, val_dataset, test_dataset, num_epochs=25) # this time train_pbr
#
# File ~/CuongVanDam/do_an_tot_nghiep/cnos/src/model/contrastive_learning_info_nce.py:1085, in train_info_nce_loss(device, model, train_loader, val_loader, num_epochs, dataset)
#    1083 for batch in tqdm(train_loader, desc=f"Epoch {epoch + 1} in training", leave=False):
#    1084     pos, anchor, neg = batch
# -> 1085     pos, anchor, neg = pos.to(device), anchor.to(device), neg.to(device)
#    1086     pos_output, anchor_output, neg_output = model(pos, anchor, neg)
#    1087     optimizer.zero_grad()
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Test

# %%
from tqdm import tqdm
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import torchvision.transforms as transforms
import torch.nn as nn
import glob
import torchvision.transforms as T
import torch

from src.model.contrastive_learning_info_nce import ContrastiveLearningModelInfoNCE
from src.model.constrastive_learning_utils import resize_and_pad_image

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")


model = ContrastiveLearningModelInfoNCE(device)
model.load_state_dict(torch.load("contrastive_learning/saved_checkpoints/icbin_best_model_checkpoint.pth"))
model = model.to(device)
# Out:
# [2024-10-18 00:11:16,023] [INFO] src.model.contrastive_learning_info_nce: model used is dinov2_vitl14
# Using cache found in /home/cuong.van-dam/.cache/torch/hub/facebookresearch_dinov2_main
# [2024-10-18 00:11:16,568] [INFO] dinov2: using MLP layer as FFN

# %%
neg = torch.stack([d[2] for d in test_dataset]).to(device).to(torch.float32)
pos = torch.stack([d[0] for d in test_dataset]).to(device).to(torch.float32)
anchor = torch.stack([d[1] for d in test_dataset]).to(device).to(torch.float32)

# %%
neg.shape
# Out:
# torch.Size([600, 3, 224, 224])

# %%
model.eval()
with torch.no_grad():
    correct, total = 0, 0
    test_loss = 0.0
    
    pos_out, anchor_out, neg_out = model(pos, anchor, neg)

import torch.nn.functional as F

# Normalize feature vectors
anchor = F.normalize(anchor_out, dim=1)
positive = F.normalize(pos_out, dim=1)
negative = F.normalize(neg_out, dim=1)

# Compute similarity scores
pos_sim = torch.sum(anchor * positive, dim=1)
neg_sim = torch.sum(anchor * negative, dim=1) 

pos_pred = torch.sum(torch.where(pos_sim>0.5,1,0))
neg_pred = torch.sum(torch.where(neg_sim<0.5,1,0))

print(pos_pred, neg_pred)
# Out:
# tensor(597, device='cuda:0') tensor(208, device='cuda:0')

# %%
pos_sim
# Out:
# tensor([0.9926, 0.9720, 0.9820, 0.9949, 0.9945, 0.8310, 0.9853, 0.9964, 0.9753,
#         0.6619, 0.8199, 0.9916, 0.9965, 0.9456, 0.9894, 0.9885, 0.9297, 0.9948,
#         0.9805, 0.8566, 0.9362, 0.9964, 0.7459, 0.9858, 0.9897, 0.9963, 0.9950,
#         0.9896, 0.9890, 0.8539, 0.9839, 0.9364, 0.9873, 0.7597, 0.9973, 0.9886,
#         0.9776, 0.9836, 0.8817, 0.8356, 0.9933, 0.9839, 0.9761, 0.9964, 0.9973,
#         0.9934, 0.9878, 0.9532, 0.9988, 0.7000, 0.9928, 0.9615, 0.9613, 0.9910,
#         0.9853, 0.9718, 0.9866, 0.9952, 0.9765, 0.9035, 0.9708, 0.8669, 0.8518,
#         0.9726, 0.8733, 0.9857, 0.6818, 0.9959, 0.4649, 0.9880, 0.9740, 0.9906,
#         0.9910, 0.9520, 0.8148, 0.7563, 0.9754, 0.7343, 0.9860, 0.9994, 0.6585,
#         0.9834, 0.9654, 0.9950, 0.9761, 0.9876, 0.8265, 0.7354, 0.9802, 0.9725,
#         0.9899, 0.9899, 0.7943, 0.9950, 0.7120, 0.9922, 0.9720, 0.9297, 0.9827,
#         0.9957, 0.7402, 0.9679, 0.9984, 0.9674, 0.9854, 0.1940, 0.8879, 0.9956,
#         0.9902, 0.9847, 0.9882, 0.9600, 0.8746, 0.9412, 0.9632, 0.9181, 0.9983,
#         0.9616, 0.9489, 0.8441, 0.9751, 0.9957, 0.9876, 0.9882, 0.9550, 0.9985,
#         0.9958, 0.7248, 0.9752, 0.9828, 0.6675, 0.9865, 0.9470, 0.9097, 0.9829,
#         0.9764, 0.9535, 0.7545, 0.9306, 0.8989, 0.9915, 0.8332, 0.9400, 0.9819,
#         0.9670, 0.9863, 0.9987, 0.9970, 0.9959, 0.9122, 0.8213, 0.9377, 0.9951,
#         0.9983, 0.7255, 0.7226, 0.9927, 0.9794, 0.9677, 0.9691, 0.7807, 0.9892,
#         0.9919, 0.7758, 0.9932, 0.9932, 0.9844, 0.9712, 0.9994, 0.9619, 0.9980,
#         0.9963, 0.9986, 0.7875, 0.9923, 0.9933, 0.9412, 0.9747, 0.9926, 0.7044,
#         0.7630, 0.7896, 0.9247, 0.9633, 0.9911, 0.9741, 0.8855, 0.9989, 0.9856,
#         0.9855, 0.7228, 0.7928, 0.9680, 0.9554, 0.8657, 0.9309, 0.8199, 0.9038,
#         0.9920, 0.9798, 0.9885, 0.8837, 0.9301, 0.9946, 0.9629, 0.9917, 0.9857,
#         0.8947, 0.9970, 0.9558, 0.9959, 0.9927, 0.9576, 0.8328, 0.9944, 0.9960,
#         0.9693, 0.8391, 0.9394, 0.9907, 0.9741, 0.9452, 0.7019, 0.9884, 0.9988,
#         0.8212, 0.9687, 0.9944, 0.9896, 0.9454, 0.7349, 0.9612, 0.9435, 0.9800,
#         0.9187, 0.7638, 0.9986, 0.9987, 0.9606, 0.9646, 0.9541, 0.9746, 0.9785,
#         0.9732, 0.9887, 0.8090, 0.8717, 0.9917, 0.9900, 0.9464, 0.9952, 0.9861,
#         0.9924, 0.9258, 0.7349, 0.7737, 0.7886, 0.9778, 0.9847, 0.8951, 0.9783,
#         0.9931, 0.9956, 0.9859, 0.9955, 0.9924, 0.9501, 0.9145, 0.8919, 0.5686,
#         0.9520, 0.9966, 0.9607, 0.9384, 0.9592, 0.9900, 0.8789, 0.9839, 0.5216,
#         0.9805, 0.9002, 0.8567, 0.8279, 0.9828, 0.9925, 0.8873, 0.9933, 0.9583,
#         0.9981, 0.9892, 0.9887, 0.8996, 0.9862, 0.9721, 0.9959, 0.9834, 0.8486,
#         0.7121, 0.9982, 0.9974, 0.9854, 0.9928, 0.9809, 0.9935, 0.8144, 0.6854,
#         0.9978, 0.7958, 0.9153, 0.9545, 0.9628, 0.9627, 0.9220, 0.9930, 0.9983,
#         0.9953, 0.9638, 0.9764, 0.9986, 0.9951, 0.9749, 0.9252, 0.9777, 0.9885,
#         0.9938, 0.8122, 0.9146, 0.9837, 0.9960, 0.9840, 0.9528, 0.9986, 0.9697,
#         0.9882, 0.9960, 0.9926, 0.9946, 0.9913, 0.8157, 0.7219, 0.9952, 0.9856,
#         0.9431, 0.9923, 0.9639, 0.9600, 0.9867, 0.9575, 0.8120, 0.8911, 0.7916,
#         0.9884, 0.9904, 0.9875, 0.9955, 0.7645, 0.8640, 0.9583, 0.9930, 0.7188,
#         0.9926, 0.9914, 0.9964, 0.9975, 0.9977, 0.8206, 0.6984, 0.9475, 0.7166,
#         0.6914, 0.9134, 0.9716, 0.9871, 0.9034, 0.9899, 0.9943, 0.9899, 0.9876,
#         0.9451, 0.7969, 0.9957, 0.8628, 0.9625, 0.9141, 0.9888, 0.9668, 0.3128,
#         0.9815, 0.9020, 0.9110, 0.9211, 0.9958, 0.9911, 0.9781, 0.8076, 0.7955,
#         0.9961, 0.9917, 0.9949, 0.9834, 0.9760, 0.9581, 0.9958, 0.9931, 0.9935,
#         0.9722, 0.9399, 0.9646, 0.9568, 0.9810, 0.9482, 0.9628, 0.8238, 0.9858,
#         0.9944, 0.9501, 0.9855, 0.9373, 0.9825, 0.9834, 0.9830, 0.9940, 0.9840,
#         0.9790, 0.8082, 0.9249, 0.9524, 0.9838, 0.9785, 0.9442, 0.9934, 0.9899,
#         0.9907, 0.9793, 0.8894, 0.9757, 0.9744, 0.8871, 0.9980, 0.9596, 0.9953,
#         0.7615, 0.9925, 0.9612, 0.9315, 0.9204, 0.9947, 0.9718, 0.9964, 0.9778,
#         0.9024, 0.9875, 0.9751, 0.9837, 0.9822, 0.8469, 0.9767, 0.9591, 0.9941,
#         0.9527, 0.9492, 0.9965, 0.8966, 0.9461, 0.7303, 0.9783, 0.7981, 0.9556,
#         0.9748, 0.9947, 0.7598, 0.9910, 0.8987, 0.9815, 0.9971, 0.7891, 0.9644,
#         0.9922, 0.6873, 0.9584, 0.9839, 0.9932, 0.9705, 0.9978, 0.9969, 0.9529,
#         0.9798, 0.7719, 0.7816, 0.7992, 0.9414, 0.9201, 0.9935, 0.9971, 0.9978,
#         0.9943, 0.9810, 0.9956, 0.9767, 0.9666, 0.9620, 0.7608, 0.9810, 0.9885,
#         0.9907, 0.9265, 0.9981, 0.9572, 0.9888, 0.9806, 0.9839, 0.9728, 0.9565,
#         0.9740, 0.9895, 0.7747, 0.9673, 0.9967, 0.9602, 0.9985, 0.9876, 0.9686,
#         0.9704, 0.9933, 0.7687, 0.9857, 0.9649, 0.9861, 0.7613, 0.9629, 0.9968,
#         0.9944, 0.9627, 0.9798, 0.9722, 0.9851, 0.9162, 0.9554, 0.9940, 0.9725,
#         0.9260, 0.7616, 0.9604, 0.9962, 0.6712, 0.9715, 0.9917, 0.9824, 0.9962,
#         0.9201, 0.9974, 0.9556, 0.9637, 0.9814, 0.9575, 0.8923, 0.9892, 0.7217,
#         0.9842, 0.9596, 0.9891, 0.9978, 0.9803, 0.9903, 0.8856, 0.9909, 0.9828,
#         0.8812, 0.9942, 0.9796, 0.9839, 0.9991, 0.9391, 0.9791, 0.9961, 0.9004,
#         0.9848, 0.9115, 0.9991, 0.9951, 0.9949, 0.9945, 0.7928, 0.9868, 0.8790,
#         0.9869, 0.9968, 0.9984, 0.9357, 0.7302, 0.9580, 0.8101, 0.9811, 0.8697,
#         0.9987, 0.7900, 0.9561, 0.9851, 0.9931, 0.9622], device='cuda:0')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
from PIL import Image
import numpy as np
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch

def resize_and_pad_image(image, target_max=224):
    '''
    input size as 3, H, W
    cnos target_max = 224
    foundpose target_max = 420
    '''

    # image = np.transpose(input_image.copy(), (2,0,1))
    # Scale image to 420
    scale_factor = target_max / torch.max(torch.tensor(image.shape)) # 420/max of x1,y1,x2,y2
    scaled_image = F.interpolate(torch.tensor(image).unsqueeze(0), scale_factor=scale_factor.item())[0] # unsqueeze at  0 - B,C, H, W
    
    # Padding 0 to 3, 420, 420
    original_h, original_w = scaled_image.shape[1:]
    original_ratio = original_w / original_h
    target_h, target_w = target_max, target_max
    target_ratio  = target_w/target_h 
    if  target_ratio != original_ratio: 
        padding_top = max((target_h - original_h) // 2, 0)
        padding_bottom = target_h - original_h - padding_top
        padding_left = max((target_w - original_w) // 2, 0)
        padding_right = target_w - original_w - padding_left
        scaled_padded_image = F.pad(
        scaled_image, (padding_left, padding_right, padding_top, padding_bottom)
        )
    else:
        scaled_padded_image = scaled_image
    
    if scaled_padded_image.shape[-1] == 223:
        scaled_padded_image = F.pad(scaled_padded_image, (0, 1, 0, 1), mode='constant', value=0)

    return scaled_padded_image


def transform_input_image(image_path, device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')):
    '''
    convert input image from Image type to correct one as in pytorch with shape as 3, h, w
    '''
    img = np.array(Image.open(image_path).convert("RGB"))/255.0
    transform_ =  transforms.Compose([
        transforms.ToTensor(), 
        transforms.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225))]
        )

    if img.shape[-1]==3:
        return resize_and_pad_image(transform_(img)).to(torch.float32).to(device)
    else:
        return resize_and_pad_image(transform_(img)).to(torch.float32).to(device)


template_path = "foundpose_analysis/icbin/templates/train_pbr/obj_000001_original/000000.png"
pos_path = "foundpose_analysis/icbin/crop1.png"
neg_path = "foundpose_analysis/icbin/crop5.png"

pos = transform_input_image(pos_path).unsqueeze(0) # conver to 1,3,h,w
anchor = transform_input_image(template_path).unsqueeze(0)
neg = transform_input_image(neg_path).unsqueeze(0)
# Out:
# /tmp/ipykernel_1722460/4173628936.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   scaled_image = F.interpolate(torch.tensor(image).unsqueeze(0), scale_factor=scale_factor.item())[0] # unsqueeze at  0 - B,C, H, W

# %%
with torch.no_grad():
    pos_out, anchor_out, neg_out = model(pos, anchor, neg)
import torch.nn.functional as F

# Normalize feature vectors
anch = F.normalize(anchor_out, dim=1)
positive = F.normalize(pos_out, dim=1)
negative = F.normalize(neg_out, dim=1)

# Compute similarity scores
pos_sim = torch.sum(anch * positive, dim=1)
neg_sim = torch.sum(anch * negative, dim=1) 

pos_pred = torch.sum(torch.where(pos_sim>0.5,1,0))
neg_pred = torch.sum(torch.where(neg_sim<0.5,1,0))

print(pos_sim, neg_sim)
# Out:
# tensor([0.9945], device='cuda:0') tensor([0.6614], device='cuda:0')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
similarity = F.cosine_similarity(negative, anch)
similarity
# Out:
# tensor([0.9839], device='cuda:0')

# %%
neg_pred
# Out:
# tensor(1008, device='cuda:0')

# %%
pred = torch.where(euclidean_distance<1,1,0)
TP = torch.sum(labels == pred)
TP
# Out:
# tensor(1227, device='cuda:0')

# %%
acc = TP/len(labels)
acc
# Out:
# tensor(1., device='cuda:0')
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
